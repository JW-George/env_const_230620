# %%
# !which python # should return /usr/local/bin/python
# !python --version
# !echo $PYTHONPATH # /env/python
#%env PYTHONPATH=
# Out:
# /usr/local/bin/python

# %%
# ! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.9.2-Linux-x86_64.sh
# ! chmod +x Miniconda3-py37_4.9.2-Linux-x86_64.sh
# ! bash ./Miniconda3-py37_4.9.2-Linux-x86_64.sh -b -f -p /usr/local
# import sys
# sys.path.append('/usr/local/lib/python3.7/site-packages/')

# %%
# !which conda  # should return /usr/local/bin/conda
# !conda --version
# !python --version
# Out:
# /usr/local/bin/conda

# %%
#!ls /usr/local/lib/python3.7/dist-packages

# %%
p = """
wfdb==2.2.1
tensorflow
"""

c = """text_file = open("requirements.txt", "w+");text_file.write(p);text_file.close()"""
exec(c)

# %%
# !conda create -n n_beats python==3.7

# %%
# 혹시 conda init 하라는 알림이 뜰 경우
# !conda init

# %%
# 먼저 가상환경 실행시키고 가상환경 확인
# !source activate n_beats && conda env list
# Out:
# # conda environments:
# #
# base                     /usr/local
# n_beats               *  /usr/local/envs/n_beats

# %%
#!conda install --channel conda-forge --file requirements.txt --yes
#!conda install requirements.txt --yes
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# failed with initial frozen solve. Retrying with flexible solve.
#
# CondaError: KeyboardInterrupt
#
# ^C
